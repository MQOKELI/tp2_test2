# %%
#All Relevent import(s)

# %%
import pandas as pd

# %%
#Reading the dataset
dataset=pd.read_csv("C:\\Users\\user\Downloads\\Informal_Settlement_Programme_-1898186875815614491.csv")
#Checking the size of the dataset
print(dataset.size)
#Checking the columns
print(dataset.columns)

#checking the datatypes
print(dataset.dtypes)

#Data slicing for my dataset where I want start form at row number 1 to row number 4
print(dataset.iloc[0:9])

# Indexing of rows again where i will index the same rows that i have been sliced
#print(dataset.loc[0,'ratio_flooded_population']) 

#Identifying missing values 
print(dataset.isnull().sum())
# Out:
# 10188
# Index(['OBJECTID', 'NAME_OF_SE', 'ALT_NAME', 'STREETNAME', 'WARD_S',
#        'PLANNING_U', 'LATITUDE', 'LONGITUDE', 'REGION', 'WATER_SUPP',
#        'SANITATION', 'REFUSE', 'ELECTRIC_2', 'UNIREFCODE', 'EST_HHC',
#        'NUSP_CAT', 'Shape__Area', 'Shape__Length'],
#       dtype='object')
# OBJECTID           int64
# NAME_OF_SE        object
# ALT_NAME          object
# STREETNAME        object
# WARD_S            object
# PLANNING_U        object
# LATITUDE          object
# LONGITUDE         object
# REGION            object
# WATER_SUPP        object
# SANITATION        object
# REFUSE            object
# ELECTRIC_2        object
# UNIREFCODE        object
# EST_HHC            int64
# NUSP_CAT          object
# Shape__Area      float64
# Shape__Length    float64
# dtype: object
#    OBJECTID     NAME_OF_SE       ALT_NAME  \
# 0         1       Amatikwe
# 1         2  Congo Phase 2  Congo Phase 2
# 2         3  Africa Inanda         Africa
# 3         4        Namibia
# ...

# %% [markdown]
# Data-types for Machine learning or Statistical analysis
# Data-types and Column with its description:
# 1)Continous numeric data- this data type is his data represents measurements where values can be fractions and
# decimals and not just whole numbers which is OBJECTID in my dataset
# 2)Nominal-Categorical data-this data type is s used to label
# variables without any quantitative value of which categories cannot be ordered
# in any meaningful way so in dataset the column of this nature is STREETNAME  .
